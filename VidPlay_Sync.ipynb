# %% [markdown]
# <a href="https://colab.research.google.com/github/secutron/ShowTime/blob/master/VidPlay_Sync.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VidPlay Sync."

# %% [markdown]
# **Mount your Google drive folder on Colab**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **Load driving video and source image**

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")


source_image = imageio.imread('/content/gdrive/My Drive/dataset/mona.png')
# push 후 우측버튼 --> 구글 드라이브로 저장(크롬확장)
driving_video = imageio.mimread('/content/gdrive/My Drive/dataset/vid11.mp4')

vid1 = imageio.mimread('/content/gdrive/My Drive/dataset/vid11-m.mp4')
vid2 = imageio.mimread('/content/gdrive/My Drive/dataset/vid11-mably.mp4')
vid3 = imageio.mimread('/content/gdrive/My Drive/dataset/vid11-se.mp4')
vid4 = imageio.mimread('/content/gdrive/My Drive/dataset/vid11-moon.mp4')
vid5 = imageio.mimread('/content/gdrive/My Drive/dataset/vid11-bae.mp4')

# %%
#Resize image and video to 256x256

source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]
vid1 = [resize(frame, (256, 256))[..., :3] for frame in vid1]
vid2 = [resize(frame, (256, 256))[..., :3] for frame in vid2]
vid3 = [resize(frame, (256, 256))[..., :3] for frame in vid3]
vid4 = [resize(frame, (256, 256))[..., :3] for frame in vid4]
vid5 = [resize(frame, (256, 256))[..., :3] for frame in vid5]


def display(source, driving, vid1=None, vid2=None, vid3=None, vid4=None, vid5=None):
    fig = plt.figure(figsize=(8 + 4 * (vid1 is not None) + 4 * (vid2 is not None) + 4 * (vid3 is not None) + 4 * (vid4 is not None) + 4 * (vid5 is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = [source]
        cols.append(driving[i])
        if vid1 is not None:
            cols.append(vid1[i])
        if vid2 is not None:
            cols.append(vid2[i])
        if vid3 is not None:
            cols.append(vid3[i])
        if vid4 is not None:
            cols.append(vid4[i])
        if vid5 is not None:
            cols.append(vid5[i])

        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])

    ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    plt.close()
    return ani
    

HTML(display(source_image, driving_video, vid1, vid2, vid3, vid4, vid5).to_html5_video())
# Out:
# <video width="2016" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...
